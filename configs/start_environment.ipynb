-- %%
-- Catalog

CREATE CATALOG IF NOT EXISTS steam_game_intelligence;

USE CATALOG steam_game_intelligence;

-- Medallion Architecture


-- Bronze: Raw / minimally processed data
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE VOLUME IF NOT EXISTS steam_game_intelligence.bronze.kaggle_data;

-- Silver: Cleaned / standardized data
CREATE SCHEMA IF NOT EXISTS silver;

-- Gold: Business / analytical data
CREATE SCHEMA IF NOT EXISTS gold;
